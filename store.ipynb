# %%
# !pip install simpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %%
import random
import simpy

# %%
# list of random vegetables
veggies = ['carrot', 'potato', 'onion', 'cabbage']
# producer process

def producer(env, store):
  while True:
    yield env.timeout(2)
    vegetable = random.choice(veggies)
    yield store.put(vegetable)
    print(f'Produced {vegetable} at {env.now :.2f}.')
    


def customer(name, env, store):
  print(f'Customer {name} arrives and requests vegetable at time {env.now :.2f}.')
  vegetable = yield store.get()
  print(f'Customer {name} got {vegetable} at {env.now :.2f} and leaves.')

  

def customer_generator(env, store):
  i = 0
  while True:
    yield env.timeout(1)
    env.process(customer(name=i, env=env, store=store))
    i+=1


env = simpy.Environment()

store = simpy.Store(env, capacity = 5)

# start producer
env.process(producer(env, store))

# start customer generator process
env.process(customer_generator(env, store))

env.run(until = 100)
# Out:
# Customer 0 arrives and requests vegetable at time 1.00.
# Customer 1 arrives and requests vegetable at time 2.00.
# Produced carrot at 2.00.
# Customer 0 got carrot at 2.00 and leaves.
# Customer 2 arrives and requests vegetable at time 3.00.
# Customer 3 arrives and requests vegetable at time 4.00.
# Produced potato at 4.00.
# Customer 1 got potato at 4.00 and leaves.
# Customer 4 arrives and requests vegetable at time 5.00.
# Customer 5 arrives and requests vegetable at time 6.00.
# Produced onion at 6.00.
# Customer 2 got onion at 6.00 and leaves.
# Customer 6 arrives and requests vegetable at time 7.00.
# Customer 7 arrives and requests vegetable at time 8.00.
# Produced onion at 8.00.
# Customer 3 got onion at 8.00 and leaves.
# Customer 8 arrives and requests vegetable at time 9.00.
# Customer 9 arrives and requests vegetable at time 10.00.
# Produced carrot at 10.00.
# Customer 4 got carrot at 10.00 and leaves.
# Customer 10 arrives and requests vegetable at time 11.00.
# Customer 11 arrives and requests vegetable at time 12.00.
# Produced onion at 12.00.
# Customer 5 got onion at 12.00 and leaves.
# Customer 12 arrives and requests vegetable at time 13.00.
# Customer 13 arrives and requests vegetable at time 14.00.
# Produced potato at 14.00.
# Customer 6 got potato at 14.00 and leaves.
# Customer 14 arrives and requests vegetable at time 15.00.
# Customer 15 arrives and requests vegetable at time 16.00.
# Produced potato at 16.00.
# Customer 7 got potato at 16.00 and leaves.
# Customer 16 arrives and requests vegetable at time 17.00.
# Customer 17 arrives and requests vegetable at time 18.00.
# Produced carrot at 18.00.
# Customer 8 got carrot at 18.00 and leaves.
# Customer 18 arrives and requests vegetable at time 19.00.
# Customer 19 arrives and requests vegetable at time 20.00.
# Produced potato at 20.00.
# Customer 9 got potato at 20.00 and leaves.
# Customer 20 arrives and requests vegetable at time 21.00.
# Customer 21 arrives and requests vegetable at time 22.00.
# Produced cabbage at 22.00.
# Customer 10 got cabbage at 22.00 and leaves.
# Customer 22 arrives and requests vegetable at time 23.00.
# Customer 23 arrives and requests vegetable at time 24.00.
# Produced cabbage at 24.00.
# Customer 11 got cabbage at 24.00 and leaves.
# Customer 24 arrives and requests vegetable at time 25.00.
# Customer 25 arrives and requests vegetable at time 26.00.
# Produced onion at 26.00.
# Customer 12 got onion at 26.00 and leaves.
# Customer 26 arrives and requests vegetable at time 27.00.
# Customer 27 arrives and requests vegetable at time 28.00.
# Produced carrot at 28.00.
# Customer 13 got carrot at 28.00 and leaves.
# Customer 28 arrives and requests vegetable at time 29.00.
# Customer 29 arrives and requests vegetable at time 30.00.
# Produced cabbage at 30.00.
# Customer 14 got cabbage at 30.00 and leaves.
# Customer 30 arrives and requests vegetable at time 31.00.
# Customer 31 arrives and requests vegetable at time 32.00.
# Produced cabbage at 32.00.
# Customer 15 got cabbage at 32.00 and leaves.
# Customer 32 arrives and requests vegetable at time 33.00.
# Customer 33 arrives and requests vegetable at time 34.00.
# Produced cabbage at 34.00.
# Customer 16 got cabbage at 34.00 and leaves.
# Customer 34 arrives and requests vegetable at time 35.00.
# Customer 35 arrives and requests vegetable at time 36.00.
# Produced onion at 36.00.
# Customer 17 got onion at 36.00 and leaves.
# Customer 36 arrives and requests vegetable at time 37.00.
# Customer 37 arrives and requests vegetable at time 38.00.
# Produced potato at 38.00.
# Customer 18 got potato at 38.00 and leaves.
# Customer 38 arrives and requests vegetable at time 39.00.
# Customer 39 arrives and requests vegetable at time 40.00.
# Produced onion at 40.00.
# Customer 19 got onion at 40.00 and leaves.
# Customer 40 arrives and requests vegetable at time 41.00.
# Customer 41 arrives and requests vegetable at time 42.00.
# Produced carrot at 42.00.
# Customer 20 got carrot at 42.00 and leaves.
# Customer 42 arrives and requests vegetable at time 43.00.
# Customer 43 arrives and requests vegetable at time 44.00.
# Produced carrot at 44.00.
# Customer 21 got carrot at 44.00 and leaves.
# Customer 44 arrives and requests vegetable at time 45.00.
# Customer 45 arrives and requests vegetable at time 46.00.
# Produced potato at 46.00.
# Customer 22 got potato at 46.00 and leaves.
# Customer 46 arrives and requests vegetable at time 47.00.
# Customer 47 arrives and requests vegetable at time 48.00.
# Produced onion at 48.00.
# Customer 23 got onion at 48.00 and leaves.
# Customer 48 arrives and requests vegetable at time 49.00.
# Customer 49 arrives and requests vegetable at time 50.00.
# Produced cabbage at 50.00.
# Customer 24 got cabbage at 50.00 and leaves.
# Customer 50 arrives and requests vegetable at time 51.00.
# Customer 51 arrives and requests vegetable at time 52.00.
# Produced onion at 52.00.
# Customer 25 got onion at 52.00 and leaves.
# Customer 52 arrives and requests vegetable at time 53.00.
# Customer 53 arrives and requests vegetable at time 54.00.
# Produced carrot at 54.00.
# Customer 26 got carrot at 54.00 and leaves.
# Customer 54 arrives and requests vegetable at time 55.00.
# Customer 55 arrives and requests vegetable at time 56.00.
# Produced carrot at 56.00.
# Customer 27 got carrot at 56.00 and leaves.
# Customer 56 arrives and requests vegetable at time 57.00.
# Customer 57 arrives and requests vegetable at time 58.00.
# Produced cabbage at 58.00.
# Customer 28 got cabbage at 58.00 and leaves.
# Customer 58 arrives and requests vegetable at time 59.00.
# Customer 59 arrives and requests vegetable at time 60.00.
# Produced carrot at 60.00.
# Customer 29 got carrot at 60.00 and leaves.
# Customer 60 arrives and requests vegetable at time 61.00.
# Customer 61 arrives and requests vegetable at time 62.00.
# Produced carrot at 62.00.
# Customer 30 got carrot at 62.00 and leaves.
# Customer 62 arrives and requests vegetable at time 63.00.
# Customer 63 arrives and requests vegetable at time 64.00.
# Produced cabbage at 64.00.
# Customer 31 got cabbage at 64.00 and leaves.
# Customer 64 arrives and requests vegetable at time 65.00.
# Customer 65 arrives and requests vegetable at time 66.00.
# Produced potato at 66.00.
# Customer 32 got potato at 66.00 and leaves.
# Customer 66 arrives and requests vegetable at time 67.00.
# Customer 67 arrives and requests vegetable at time 68.00.
# Produced onion at 68.00.
# Customer 33 got onion at 68.00 and leaves.
# Customer 68 arrives and requests vegetable at time 69.00.
# Customer 69 arrives and requests vegetable at time 70.00.
# Produced carrot at 70.00.
# Customer 34 got carrot at 70.00 and leaves.
# Customer 70 arrives and requests vegetable at time 71.00.
# Customer 71 arrives and requests vegetable at time 72.00.
# Produced potato at 72.00.
# Customer 35 got potato at 72.00 and leaves.
# Customer 72 arrives and requests vegetable at time 73.00.
# Customer 73 arrives and requests vegetable at time 74.00.
# Produced cabbage at 74.00.
# Customer 36 got cabbage at 74.00 and leaves.
# Customer 74 arrives and requests vegetable at time 75.00.
# Customer 75 arrives and requests vegetable at time 76.00.
# Produced onion at 76.00.
# Customer 37 got onion at 76.00 and leaves.
# Customer 76 arrives and requests vegetable at time 77.00.
# Customer 77 arrives and requests vegetable at time 78.00.
# Produced carrot at 78.00.
# Customer 38 got carrot at 78.00 and leaves.
# Customer 78 arrives and requests vegetable at time 79.00.
# Customer 79 arrives and requests vegetable at time 80.00.
# Produced cabbage at 80.00.
# Customer 39 got cabbage at 80.00 and leaves.
# Customer 80 arrives and requests vegetable at time 81.00.
# Customer 81 arrives and requests vegetable at time 82.00.
# Produced onion at 82.00.
# Customer 40 got onion at 82.00 and leaves.
# Customer 82 arrives and requests vegetable at time 83.00.
# Customer 83 arrives and requests vegetable at time 84.00.
# Produced onion at 84.00.
# Customer 41 got onion at 84.00 and leaves.
# Customer 84 arrives and requests vegetable at time 85.00.
# Customer 85 arrives and requests vegetable at time 86.00.
# Produced onion at 86.00.
# Customer 42 got onion at 86.00 and leaves.
# Customer 86 arrives and requests vegetable at time 87.00.
# Customer 87 arrives and requests vegetable at time 88.00.
# Produced cabbage at 88.00.
# Customer 43 got cabbage at 88.00 and leaves.
# Customer 88 arrives and requests vegetable at time 89.00.
# Customer 89 arrives and requests vegetable at time 90.00.
# Produced cabbage at 90.00.
# Customer 44 got cabbage at 90.00 and leaves.
# Customer 90 arrives and requests vegetable at time 91.00.
# Customer 91 arrives and requests vegetable at time 92.00.
# Produced cabbage at 92.00.
# Customer 45 got cabbage at 92.00 and leaves.
# Customer 92 arrives and requests vegetable at time 93.00.
# Customer 93 arrives and requests vegetable at time 94.00.
# Produced onion at 94.00.
# Customer 46 got onion at 94.00 and leaves.
# Customer 94 arrives and requests vegetable at time 95.00.
# Customer 95 arrives and requests vegetable at time 96.00.
# Produced carrot at 96.00.
# Customer 47 got carrot at 96.00 and leaves.
# Customer 96 arrives and requests vegetable at time 97.00.
# Customer 97 arrives and requests vegetable at time 98.00.
# Produced onion at 98.00.
# Customer 48 got onion at 98.00 and leaves.
# Customer 98 arrives and requests vegetable at time 99.00.

# %% [markdown]
# ### Priority Store

# %%
# producer process

def producer(env, store):
  while True:
    yield env.timeout(1)
    vegetable_name = 'potato'
    expires_in = env.now + random.randint(1, 10)
    vegetable = simpy.PriorityItem(priority=expires_in, item=vegetable_name)
    yield store.put(vegetable)
    print(f'Produced {vegetable} at {env.now :.2f}.')
    


def customer(name, env, store):
  print(f'Customer {name} arrives and requests potato at time {env.now :.2f}.')
  vegetable = yield store.get()
  print(f'Customer {name} got {vegetable} at {env.now :.2f} and leaves.')

  

def customer_generator(env, store):
  i = 0
  while True:
    yield env.timeout(3)
    env.process(customer(name=i, env=env, store=store))
    i+=1


env = simpy.Environment()

store = simpy.PriorityStore(env, capacity = 5)

# start producer
env.process(producer(env, store))

# start customer generator process
env.process(customer_generator(env, store))

env.run(until = 20)
# Out:
# Produced PriorityItem(priority=5, item='potato') at 1.00.
# Produced PriorityItem(priority=10, item='potato') at 2.00.
# Customer 0 arrives and requests potato at time 3.00.
# Customer 0 got PriorityItem(priority=5, item='potato') at 3.00 and leaves.
# Produced PriorityItem(priority=7, item='potato') at 3.00.
# Produced PriorityItem(priority=5, item='potato') at 4.00.
# Produced PriorityItem(priority=10, item='potato') at 5.00.
# Customer 1 arrives and requests potato at time 6.00.
# Customer 1 got PriorityItem(priority=5, item='potato') at 6.00 and leaves.
# Produced PriorityItem(priority=9, item='potato') at 6.00.
# Produced PriorityItem(priority=10, item='potato') at 7.00.
# Customer 2 arrives and requests potato at time 9.00.
# Customer 2 got PriorityItem(priority=7, item='potato') at 9.00 and leaves.
# Produced PriorityItem(priority=14, item='potato') at 9.00.
# Customer 3 arrives and requests potato at time 12.00.
# Customer 3 got PriorityItem(priority=9, item='potato') at 12.00 and leaves.
# Produced PriorityItem(priority=15, item='potato') at 12.00.
# Customer 4 arrives and requests potato at time 15.00.
# Customer 4 got PriorityItem(priority=10, item='potato') at 15.00 and leaves.
# Produced PriorityItem(priority=21, item='potato') at 15.00.
# Customer 5 arrives and requests potato at time 18.00.
# Customer 5 got PriorityItem(priority=10, item='potato') at 18.00 and leaves.
# Produced PriorityItem(priority=19, item='potato') at 18.00.

# %% [markdown]
# ### Filter Store

# %%
# list of random vegetables
veggies = ['carrot', 'potato', 'onion', 'cabbage']
# producer process

def producer(env, store):
  while True:
    yield env.timeout(2)
    vegetable = random.choice(veggies)
    yield store.put(vegetable)
    print(f'Produced {vegetable} at {env.now :.2f}.')
    


def customer(name, env, store):
  reqd_veg = random.choice(veggies)
  print(f'Customer {name} arrives and requests vegetable {reqd_veg} at time {env.now :.2f}.')
  vegetable = yield store.get(lambda vegetable: vegetable == reqd_veg)
  print(f'Customer {name} got {vegetable} at {env.now :.2f} and leaves.')

  

def customer_generator(env, store):
  i = 0
  while True:
    yield env.timeout(1)
    env.process(customer(name=i, env=env, store=store))
    i+=1


env = simpy.Environment()

store = simpy.FilterStore(env, capacity = 5)

# start producer
env.process(producer(env, store))

# start customer generator process
env.process(customer_generator(env, store))

env.run(until = 20)
# Out:
# Customer 0 arrives and requests vegetable carrot at time 1.00.
# Customer 1 arrives and requests vegetable onion at time 2.00.
# Produced onion at 2.00.
# Customer 1 got onion at 2.00 and leaves.
# Customer 2 arrives and requests vegetable onion at time 3.00.
# Customer 3 arrives and requests vegetable carrot at time 4.00.
# Produced carrot at 4.00.
# Customer 0 got carrot at 4.00 and leaves.
# Customer 4 arrives and requests vegetable onion at time 5.00.
# Customer 5 arrives and requests vegetable onion at time 6.00.
# Produced onion at 6.00.
# Customer 2 got onion at 6.00 and leaves.
# Customer 6 arrives and requests vegetable cabbage at time 7.00.
# Customer 7 arrives and requests vegetable onion at time 8.00.
# Produced onion at 8.00.
# Customer 4 got onion at 8.00 and leaves.
# Customer 8 arrives and requests vegetable cabbage at time 9.00.
# Customer 9 arrives and requests vegetable carrot at time 10.00.
# Produced onion at 10.00.
# Customer 5 got onion at 10.00 and leaves.
# Customer 10 arrives and requests vegetable onion at time 11.00.
# Customer 11 arrives and requests vegetable carrot at time 12.00.
# Produced potato at 12.00.
# Customer 12 arrives and requests vegetable onion at time 13.00.
# Customer 13 arrives and requests vegetable carrot at time 14.00.
# Produced potato at 14.00.
# Customer 14 arrives and requests vegetable carrot at time 15.00.
# Customer 15 arrives and requests vegetable carrot at time 16.00.
# Produced onion at 16.00.
# Customer 7 got onion at 16.00 and leaves.
# Customer 16 arrives and requests vegetable potato at time 17.00.
# Customer 16 got potato at 17.00 and leaves.
# Customer 17 arrives and requests vegetable carrot at time 18.00.
# Produced cabbage at 18.00.
# Customer 6 got cabbage at 18.00 and leaves.
# Customer 18 arrives and requests vegetable carrot at time 19.00.
