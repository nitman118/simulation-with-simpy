# %%
# !pip install simpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %%
import simpy
import random

# %%
def coffee_machine(env):
  while True:
    print(f"Coffee machine ready to use at {env.now: .2f}.")
    random_running_out_of_coffee = random.uniform(60, 180) # minutes
    yield env.timeout(random_running_out_of_coffee)
    print(f"Coffee over! Call operator at {env.now:.2f}.")
    refill = env.event()
    print(f"Created refill event. Refill triggered attribute: {refill.triggered} at {env.now: .2f}.")
    
    env.process(refilling(env, refill))
    yield refill

def refilling(env, refill):
  refill_time = 15 #minutes
  yield env.timeout(refill_time)
  refill.succeed()
  print(f"Created refill event. Refill triggered attribute: {refill.triggered} at {env.now: .2f}.")
  
  clean_floor_time = 5 #minutes
  yield env.timeout(clean_floor_time)
  print(f"Floor cleaned. Operator leaves at {env.now: .2f}.")




env = simpy.Environment()

env.process(coffee_machine(env))

env.run(until=24*60)
# Out:
# Coffee machine ready to use at  0.00.
# Coffee over! Call operator at 115.22.
# Created refill event. Refill triggered attribute: False at  115.22.
# Created refill event. Refill triggered attribute: True at  130.22.
# Coffee machine ready to use at  130.22.
# Floor cleaned. Operator leaves at  135.22.
# Coffee over! Call operator at 225.46.
# Created refill event. Refill triggered attribute: False at  225.46.
# Created refill event. Refill triggered attribute: True at  240.46.
# Coffee machine ready to use at  240.46.
# Floor cleaned. Operator leaves at  245.46.
# Coffee over! Call operator at 357.80.
# Created refill event. Refill triggered attribute: False at  357.80.
# Created refill event. Refill triggered attribute: True at  372.80.
# Coffee machine ready to use at  372.80.
# Floor cleaned. Operator leaves at  377.80.
# Coffee over! Call operator at 456.59.
# Created refill event. Refill triggered attribute: False at  456.59.
# Created refill event. Refill triggered attribute: True at  471.59.
# Coffee machine ready to use at  471.59.
# Floor cleaned. Operator leaves at  476.59.
# Coffee over! Call operator at 602.45.
# Created refill event. Refill triggered attribute: False at  602.45.
# Created refill event. Refill triggered attribute: True at  617.45.
# Coffee machine ready to use at  617.45.
# Floor cleaned. Operator leaves at  622.45.
# Coffee over! Call operator at 778.30.
# Created refill event. Refill triggered attribute: False at  778.30.
# Created refill event. Refill triggered attribute: True at  793.30.
# Coffee machine ready to use at  793.30.
# Floor cleaned. Operator leaves at  798.30.
# Coffee over! Call operator at 854.55.
# Created refill event. Refill triggered attribute: False at  854.55.
# Created refill event. Refill triggered attribute: True at  869.55.
# Coffee machine ready to use at  869.55.
# Floor cleaned. Operator leaves at  874.55.
# Coffee over! Call operator at 956.03.
# Created refill event. Refill triggered attribute: False at  956.03.
# Created refill event. Refill triggered attribute: True at  971.03.
# Coffee machine ready to use at  971.03.
# Floor cleaned. Operator leaves at  976.03.
# Coffee over! Call operator at 1047.62.
# Created refill event. Refill triggered attribute: False at  1047.62.
# Created refill event. Refill triggered attribute: True at  1062.62.
# Coffee machine ready to use at  1062.62.
# Floor cleaned. Operator leaves at  1067.62.
# Coffee over! Call operator at 1181.38.
# Created refill event. Refill triggered attribute: False at  1181.38.
# Created refill event. Refill triggered attribute: True at  1196.38.
# Coffee machine ready to use at  1196.38.
# Floor cleaned. Operator leaves at  1201.38.
# Coffee over! Call operator at 1266.01.
# Created refill event. Refill triggered attribute: False at  1266.01.
# Created refill event. Refill triggered attribute: True at  1281.01.
# Coffee machine ready to use at  1281.01.
# Floor cleaned. Operator leaves at  1286.01.
# Coffee over! Call operator at 1403.94.
# Created refill event. Refill triggered attribute: False at  1403.94.
# Created refill event. Refill triggered attribute: True at  1418.94.
# Coffee machine ready to use at  1418.94.
# Floor cleaned. Operator leaves at  1423.94.
